# %%
from xpacs import *
import pandas as pd
import matplotlib.pyplot as plt



#loading a toy example
#get the topk candidate rules
cluster_number = 3
cluster_id = 0
mass_threshold = 0.4
purity_threshold = 0.5
dataset = "pkdd1998"

with open('results/%s/cluster%d_idx%d_candidates.txt' %(dataset, cluster_number, cluster_id),'rb') as f:
    candidates = pickle.load(f)
#print(candidates)
scores = candidates[1]

plt.scatter([i[0] for i in scores], [i[1] for i in scores], label = "current scores")
plt.scatter([1.0],[1.0], label= "ideal")
x = [i[0] for i in scores]
y = [i[1] for i in scores]
dist = np.square((np.array(x) - 1.0)) + np.square((np.array(y) - 1.0))
plt.scatter(x[np.argmin(dist)], y[np.argmin(dist)], label = "least distant")
plt.xlabel("mass/coverage")
plt.ylabel("purity")
plt.legend()
plt.title("best_rule:%s" % str(candidates[0][np.argmin(dist)]))
#plt.savefig("results/%s/cluster%d_idx%d_candidates_score_plot.pdf" %(dataset, cluster_number, cluster_id))

group0_anomaly = pd.read_csv('results/%s/cluster%d_idx%d_group_anomaly.txt'%(dataset, cluster_number, cluster_id),index_col = 0)
group0_anomaly = group0_anomaly.reset_index()
del group0_anomaly['index']
normal_X = pd.read_csv('results/%s/normal_data.txt' % dataset)


found_results = find_displaying_candidate_above_threshold(group0_anomaly,
                                         normal_X, 
                                         candidates=candidates[0],
                                         candidate_scores = candidates[1], 
                                         mass=mass_threshold, 
                                         purity=purity_threshold)
print("results found:", found_results[0])
print("scores found:", found_results[1])
# Out:
# results found: [[(1, ('TRANSFER TO ACCOUNT', 'TRANSFER TO ACCOUNT')), (3, (44923.22471436973, 47125.65118484468)), (5, ('unknown', 'unknown'))], [(2, (38841.21650678054, 39806.053362914114)), (4, ('ST', 'ST'))], [(0, ('ISSUE', 'ISSUE')), (1, ('TRANSFER TO ACCOUNT', 'TRANSFER TO ACCOUNT')), (2, (38841.21650678054, 39806.053362914114))]]
# scores found: [[0.4473684210526316, 0.7391304347826086], [0.42105263157894735, 1.0], [0.42105263157894735, 1.0]]

# %%
#calculcate the results for a particular rule
rule = [(5, ('unknown', 'unknown'))]


#other values needed
cluster_number = 3
cluster_id = 0

with open('results/%s/cluster%d_idx%d_candidates.txt' %(dataset, cluster_number, cluster_id),'rb') as f:
    candidates = pickle.load(f)

group0_anomaly = pd.read_csv('results/%s/cluster%d_idx%d_group_anomaly.txt'%(dataset, cluster_number, cluster_id),index_col = 0)

x0 = group0_anomaly.iloc[0]
cat_idx_lst = []
for i in group0_anomaly.columns:
    if type(x0[i]) == str:
        cat_idx_lst.append(i)

normal_X = pd.read_csv('results/%s/normal_data.txt' % dataset)
group0_anomaly = group0_anomaly.reset_index()
del group0_anomaly['index']
mass_purity_score= get_mass_purity(group0_anomaly, normal_X, rule, feature_names = list(group0_anomaly.columns),
                                   cat_idx_lst = cat_idx_lst)
print("Score:", mass_purity_score)
# Out:
# Score: (0.02631578947368421, 0.5)

# %%
group0_anomaly.loc[group0_anomaly['k_symbol']== "unknown"]
# Out:
#      type            operation   amount  balance bank k_symbol
# 5   ISSUE  TRANSFER TO ACCOUNT  42638.0  47963.0   YZ  unknown
# 6   ISSUE  TRANSFER TO ACCOUNT  42849.0  47627.0   YZ  unknown
# 7   ISSUE  TRANSFER TO ACCOUNT  42303.0  47888.0   YZ  unknown
# 8   ISSUE  TRANSFER TO ACCOUNT  13459.0  86072.0   ST  unknown
# 9   ISSUE  TRANSFER TO ACCOUNT  42683.0  46231.0   YZ  unknown
# 10  ISSUE  TRANSFER TO ACCOUNT  42476.0  46608.0   YZ  unknown
# 11  ISSUE  TRANSFER TO ACCOUNT  42354.0  46459.0   YZ  unknown
# 13  ISSUE  TRANSFER TO ACCOUNT  42647.0  45549.0   YZ  unknown
# 14  ISSUE  TRANSFER TO ACCOUNT  42653.0  45398.0   YZ  unknown
# 15  ISSUE  TRANSFER TO ACCOUNT  13379.0  84138.0   KL  unknown
# 16  ISSUE  TRANSFER TO ACCOUNT  42581.0  45421.0   YZ  unknown
# 17  ISSUE  TRANSFER TO ACCOUNT  42655.0  44209.0   YZ  unknown
# 18  ISSUE  TRANSFER TO ACCOUNT  42653.0  44846.0   YZ  unknown
# 19  ISSUE  TRANSFER TO ACCOUNT  39413.0  47430.0   ST  unknown
# 20  ISSUE  TRANSFER TO ACCOUNT  39199.0  43739.0   ST  unknown
# 21  ISSUE  TRANSFER TO ACCOUNT  39096.0  45720.0   ST  unknown
# 22  ISSUE  TRANSFER TO ACCOUNT  39464.0  46978.0   ST  unknown
# 23  ISSUE  TRANSFER TO ACCOUNT  10734.0  87011.0   EF  unknown
# 24  ISSUE  TRANSFER TO ACCOUNT  39331.0  47020.0   ST  unknown
# 25  ISSUE  TRANSFER TO ACCOUNT  39235.0  43951.0   ST  unknown
# 26  ISSUE  TRANSFER TO ACCOUNT  39374.0  44388.0   ST  unknown
# 27  ISSUE  TRANSFER TO ACCOUNT  39372.0  43634.0   ST  unknown
# 28  ISSUE  TRANSFER TO ACCOUNT  39245.0  46409.0   ST  unknown
# 29  ISSUE  TRANSFER TO ACCOUNT  39216.0  46470.0   ST  unknown
# 30  ISSUE  TRANSFER TO ACCOUNT  39549.0  46647.0   ST  unknown
# 31  ISSUE  TRANSFER TO ACCOUNT  39318.0  45861.0   ST  unknown
# 32  ISSUE  TRANSFER TO ACCOUNT  39390.0  45038.0   ST  unknown
# 33  ISSUE  TRANSFER TO ACCOUNT  39444.0  46321.0   ST  unknown
# 34  ISSUE  TRANSFER TO ACCOUNT  39326.0  45209.0   ST  unknown
# 36  ISSUE  TRANSFER TO ACCOUNT  39341.0  46222.0   ST  unknown

# %%
normal_X.loc[normal_X['k_symbol']== "unknown"]
# Out:
#       type            operation   amount  balance bank k_symbol
# 0    ISSUE  TRANSFER TO ACCOUNT   8520.0  81428.0   CD  unknown
# 1    ISSUE  TRANSFER TO ACCOUNT   8167.0  68157.0   CD  unknown
# 2    ISSUE  TRANSFER TO ACCOUNT   7758.0  79300.0   CD  unknown
# 3    ISSUE  TRANSFER TO ACCOUNT   6033.0  73736.0   CD  unknown
# 4    ISSUE  TRANSFER TO ACCOUNT   8292.0  79907.0   CD  unknown
# ..     ...                  ...      ...      ...  ...      ...
# 780  ISSUE  TRANSFER TO ACCOUNT  12305.0  63845.0   IJ  unknown
# 821  ISSUE  TRANSFER TO ACCOUNT      1.0  27759.0   WX  unknown
# 835  ISSUE  TRANSFER TO ACCOUNT    607.0  34134.0   IJ  unknown
# 850  ISSUE  TRANSFER TO ACCOUNT    642.0  30011.0   WX  unknown
# 906  ISSUE  TRANSFER TO ACCOUNT      1.0  30046.0   WX  unknown
#
# [219 rows x 6 columns]

# %%
36/ (219 + 36)
# Out:
# 0.1411764705882353
